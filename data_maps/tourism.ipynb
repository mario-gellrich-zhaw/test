# %% [markdown]
# # Libraries

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/project_arm_airbnb/data_maps

# %% [markdown]
# ## API request

# %% [markdown]
# ### Touristenattraktionen

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-2"="CH-GE"][admin_level=4];
        node ["tourism"="attraction"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('attraction.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df_attraction = json_normalize(data)

# Number of rows and columns
print(df_attraction.shape)

# First rows
df_attraction.head(5)
# Out:
# (37, 57)
#    type         id        lat       lon      tags.addr:street tags.amenity  \
# 0  node   60018172  46.207381  6.155889  Jetée des Eaux Vives     fountain
# 1  node  139446272  46.128550  5.957381                   NaN          NaN
# 2  node  151258480  46.132357  5.955911                   NaN          NaN
# 3  node  613159167  46.142711  6.126112                   NaN          NaN
# 4  node  916320563  46.224280  6.138078                   NaN          NaN
#
#   tags.bottle tags.dog tags.drinking_water tags.fountain  ...  \
# 0          no       no                  no     jet_water  ...
# 1         NaN      NaN                 NaN           NaN  ...
# 2         NaN      NaN                 NaN           NaN  ...
# 3         NaN      NaN                 NaN           NaN  ...
# 4         NaN      NaN                 NaN           NaN  ...
#
#   tags.internet_access tags.leisure tags.level tags.opening_hours  \
# 0                  NaN          NaN        NaN                NaN
# 1                  NaN          NaN        NaN                NaN
# 2                  NaN          NaN        NaN                NaN
# 3                  NaN          NaN        NaN                NaN
# 4                  NaN          NaN        NaN                NaN
#
#   tags.denotation tags.geological tags.length tags.url tags.width tags.alt
# 0             NaN             NaN         NaN      NaN        NaN      NaN
# 1             NaN             NaN         NaN      NaN        NaN      NaN
# 2             NaN             NaN         NaN      NaN        NaN      NaN
# 3             NaN             NaN         NaN      NaN        NaN      NaN
# 4             NaN             NaN         NaN      NaN        NaN      NaN
#
# [5 rows x 57 columns]

# %%
# load data from df_attraction intro locations_attraction
locations_attraction = df_attraction[['lat','lon', "tags.name"]]

#Create map
m = folium.Map(location=[46.2044, 6.1432], zoom_start=12)

# add marker to sympols
for i in range(0, len(locations_attraction)):
    folium.Marker([locations_attraction.iloc[i]['lat'], locations_attraction.iloc[i]['lon']],
                  popup=locations_attraction.iloc[i]['tags.name']).add_to(m)
    
# plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50bce05fe110a6881bc3b838f5d725a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50bce05fe110a6881bc3b838f5d725a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50bce05fe110a6881bc3b838f5d725a6 = L.map(
#                 &quot;map_50bce05fe110a6881bc3b838f5d725a6&quot;,
#                 {
#                     center: [46.2044, 6.1432],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2f6206cae4bf66baca339179ae28264 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d2f6206cae4bf66baca339179ae28264.addTo(map_50bce05fe110a6881bc3b838f5d725a6);
#
#
#             var marker_1cc4081f812a9a68b16e326747a09266 = L.marker(
#                 [46.2073807, 6.1558891],
#                 {}
#             ).addTo(map_50bce05fe110a6881bc3b838f5d725a6);
#
#
#         var popup_c12b75c5a95147bd0da3dcf2d9ac543a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab345d258db514215177d6830ce89107 = $(`&lt;div id=&quot;html_ab345d258db514215177d6830ce89107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jet d&#x27;eau&lt;/div&gt;`)[0];
#                 popup_c12b75c5a95147bd0da3dcf2d9ac543a.setContent(html_ab345d258db514215177d6830ce89107);
#
#
#
#         marker_1cc4081f812a9a68b16e326747a09266.bindPopup(popup_c12b75c5a95147bd0da3dcf2d9ac543a)
#         ;
#
#
#
#
#             var marker_6dd03469083755d3633eea6ae386443d = L.marker(
#                 [46.1285501, 5.9573812],
#                 {}
#             ).addTo(map_50bce05fe110a6881bc3b838f5d725a6);
#
#
#         var popup_571c1fc0ddf60d6c4604ba9d72a28ff5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52441e93b06e8b908f5675fbea102c9e = $(`&lt;div id=&quot;html_52441e93b06e8b908f5675fbea102c9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Borne n°1&lt;/div&gt;`)[0];
#                 popup_571c1fc0ddf60d6c4604ba9d72a28ff5.setContent(html_52441e93b06e8b908f5675fbea102c9e);
#
#
#
#         marker_6dd03469083755d3633eea6ae386443d.bindPopup(popup_571c1fc0ddf60d6c4604ba9d72a28ff5)
#         ;
#
#
#
#
#             var marker_2d0d91fdc1ed3466ce990148606eb3ff = L.marker(
#                 [46.1323565, 5.9559113],
#                 {}
#             ).addTo(map_50bce05fe110a6881bc3b838f5d725a6);
#
#
#         var popup_61601f489a28f77f82e58a986ab915b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b4a4f6603787dfa91e99565a0797d74 = $(`&lt;div id=&quot;html_8b4a4f6603787dfa91e99565a0797d74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Le point le plus occidental de Suisse&lt;/div&gt;`)[0];
#                 popup_61601f489a28f77f82e58a986ab915b5.setContent(html_8b4a4f6603787dfa91e99565a0797d74);
#
#
#
#         marker_2d0d91fdc1ed3466ce990148606eb3ff.bindPopup(popup_61601f489a28f77f82e58a986ab915b5)
#         ;
#
#
#
#
#             var marker_4b9ddef4120ff1bd7d8bcfa611a1ffe7 = L.marker(
#                 [46.1427106, 6.126112],
#                 {}
#             ).addTo(map_50bce05fe110a6881bc3b838f5d725a6);
#
#
#         var popup_4bbae4f68c549d9bd3db644c0c04f860 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e8e444526011fd1a320b8e83d63145c = $(`&lt;div id=&quot;html_8e8e444526011fd1a320b8e83d63145c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#                 popup_4bbae4f68c549d9bd3db644c0c04f860.setContent(html_8e8e444526011fd1a320b8e83d63145c);
#
#
#
#         marker_4b9ddef4120ff1bd7d8bcfa611a1ffe7.bindPopup(popup_4bbae4f68c549d9bd3db644c0c04f860)
#         ;
#
#
#
#
#             var marker_cde77bc74ff784fbbdfc2a7a8c99d1ba = L.marker(
#                 [46.2242798, 6.1380784],
#                 {}
#             ).addTo(map_50bce05fe110a6881bc3b838f5d725a6);
#
#
#         var popup_6a8c1f5133457bd93a184660668f3d93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0b16d597de05799294da30430a8446a = $(`&lt;div id=&quot;html_b0b16d597de05799294da30430a8446a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cloche de Shinagawa&lt;/div&gt;`)[0];
#                 popup_6a8c1f5133457bd93a184660668f3d93.setContent(html_b0b16d597de05799294da30430a8446a);
#
#
#
#         marker_cde77bc74ff784fbbdfc2a7a8c99d1ba.bindPopup(popup_6a8c1f5133457bd93a184660668f3d93)
#         ;
#
#
#
#
#             var marker_db87267e995090f4a5e4a056b14614e5 = L.marker(
#                 [46.2325449, 6.0552594],
#                 {}
#             ).addTo(map_50bce05fe110a6881

# %% [markdown]
# ## Museum

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-2"="CH-GE"][admin_level=4];
        node ["tourism"="museum"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('museum.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df_museum = json_normalize(data)

# Number of rows and columns
print(df_museum.shape)

# First rows
df_museum.head(5)
# Out:
# (15, 41)
#    type          id        lat       lon tags.fee tags.museum  \
# 0  node   701851300  46.233972  6.055721       no     science
# 1  node   981690477  46.184291  6.139151       no         NaN
# 2  node   983366077  46.198282  6.108982      NaN         NaN
# 3  node  1768216261  46.220829  6.152126       no         NaN
# 4  node  2021513198  46.198828  6.137523      yes         art
#
#                                 tags.name  \
# 0  Globe de la Science et de l'Innovation
# 1                        Musée de Carouge
# 2                           Musée des EAN
# 3           Musée d'histoire des sciences
# 4                                   MAMCO
#
#                           tags.name:en  \
# 0  The Globe of Science and Innovation
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                              tags.name:es  \
# 0  Globo de la Ciencia y de la Innovación
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                              tags.name:fr  ...  \
# 0  Globe de la Science et de L'innovation  ...
# 1                                     NaN  ...
# 2                           Musée des EAN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
#
#                   tags.contact:twitter     tags.email  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4  https://twitter.com/mamco_artmuseum  info@mamco.ch
#
#                     tags.official_name tags.short_name tags.addr:housename  \
# 0                                  NaN             NaN                 NaN
# 1                                  NaN             NaN                 NaN
# 2                                  NaN             NaN                 NaN
# 3                                  NaN             NaN                 NaN
# 4  Musée d’Art Moderne et Contemporain           MAMCO                 NaN
#
#   tags.operator:type tags.description tags.internet_access  \
# 0                NaN              NaN                  NaN
# 1                NaN              NaN                  NaN
# 2                NaN              NaN                  NaN
# 3                NaN              NaN                  NaN
# 4                NaN              NaN                  NaN
#
#   tags.contact:website tags.check_date
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
#
# [5 rows x 41 columns]

# %%
# load data from df_museum intro locations_museum
locations_museum = df_museum[['lat','lon', "tags.name"]]

#Create map
m = folium.Map(location=[46.2044, 6.1432], zoom_start=12)

# add marker to sympols
for i in range(0, len(locations_museum)):
    folium.Marker([locations_museum.iloc[i]['lat'], locations_museum.iloc[i]['lon']],
                  popup=locations_museum.iloc[i]['tags.name']).add_to(m)
    
# plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b48570d1ad3a5e0d39724a78134fc27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b48570d1ad3a5e0d39724a78134fc27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b48570d1ad3a5e0d39724a78134fc27 = L.map(
#                 &quot;map_3b48570d1ad3a5e0d39724a78134fc27&quot;,
#                 {
#                     center: [46.2044, 6.1432],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cb1a5795af2e65551a0a943b4cb8262 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1cb1a5795af2e65551a0a943b4cb8262.addTo(map_3b48570d1ad3a5e0d39724a78134fc27);
#
#
#             var marker_c076e6bd5952204034893b6ba0a03d7e = L.marker(
#                 [46.2339717, 6.0557211],
#                 {}
#             ).addTo(map_3b48570d1ad3a5e0d39724a78134fc27);
#
#
#         var popup_f53a037dc38b6d25743d6040b3c0e61f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bf288fec9cd833cfdd1de599f79c6dc = $(`&lt;div id=&quot;html_9bf288fec9cd833cfdd1de599f79c6dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Globe de la Science et de l&#x27;Innovation&lt;/div&gt;`)[0];
#                 popup_f53a037dc38b6d25743d6040b3c0e61f.setContent(html_9bf288fec9cd833cfdd1de599f79c6dc);
#
#
#
#         marker_c076e6bd5952204034893b6ba0a03d7e.bindPopup(popup_f53a037dc38b6d25743d6040b3c0e61f)
#         ;
#
#
#
#
#             var marker_3d7534f5c37b34d7050daec42a41aa11 = L.marker(
#                 [46.1842913, 6.1391515],
#                 {}
#             ).addTo(map_3b48570d1ad3a5e0d39724a78134fc27);
#
#
#         var popup_262f2ce734312a47576af93aa3339012 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_097d2844a5b18d3956fdabf6d7c74f95 = $(`&lt;div id=&quot;html_097d2844a5b18d3956fdabf6d7c74f95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée de Carouge&lt;/div&gt;`)[0];
#                 popup_262f2ce734312a47576af93aa3339012.setContent(html_097d2844a5b18d3956fdabf6d7c74f95);
#
#
#
#         marker_3d7534f5c37b34d7050daec42a41aa11.bindPopup(popup_262f2ce734312a47576af93aa3339012)
#         ;
#
#
#
#
#             var marker_0a88f499ea63e6c029551e88be1471cb = L.marker(
#                 [46.1982817, 6.1089823],
#                 {}
#             ).addTo(map_3b48570d1ad3a5e0d39724a78134fc27);
#
#
#         var popup_77d51d7d84c8adc2ca94cf1aa7e9c820 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8fb12ad71527fc472470b1f86a1eb70 = $(`&lt;div id=&quot;html_d8fb12ad71527fc472470b1f86a1eb70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée des EAN&lt;/div&gt;`)[0];
#                 popup_77d51d7d84c8adc2ca94cf1aa7e9c820.setContent(html_d8fb12ad71527fc472470b1f86a1eb70);
#
#
#
#         marker_0a88f499ea63e6c029551e88be1471cb.bindPopup(popup_77d51d7d84c8adc2ca94cf1aa7e9c820)
#         ;
#
#
#
#
#             var marker_8b3830de9eb4c6e2a9d22c599b7f1e52 = L.marker(
#                 [46.2208287, 6.1521265],
#                 {}
#             ).addTo(map_3b48570d1ad3a5e0d39724a78134fc27);
#
#
#         var popup_ffc7080c87642ed5599b4c7288194d5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab268c6472ce9fee9dfbca2f71344b72 = $(`&lt;div id=&quot;html_ab268c6472ce9fee9dfbca2f71344b72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée d&#x27;histoire des sciences&lt;/div&gt;`)[0];
#                 popup_ffc7080c87642ed5599b4c7288194d5c.setContent(html_ab268c6472ce9fee9dfbca2f71344b72);
#
#
#
#         marker_8b3830de9eb4c6e2a9d22c599b7f1e52.bindPopup(popup_ffc7080c87642ed5599b4c7288194d5c)
#         ;
#
#
#
#
#             var marker_3345495e2299147ac5f630035144727d = L.marker(
#                 [46.1988283, 6.1375228],
#                 {}
#             ).addTo(map_3b48570d1ad3a5e0d39724a78134fc27);
#
#
#         var popup_6e3be56248f3c62b0fad1adf867816b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6533b7751592e8bea3751ef7627ab64f = $(`&lt;div id=&quot;html_6533b7751592e8bea3751ef7627ab64f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAMCO&lt;/div&gt;`)[0];
#                 popup_6e3be56248f3c62b0fad1adf867816b4.setContent(html_6533b7751592e8bea3751ef7627ab64f);
#
#
#
#         marker_3345495e2299147ac5f630035144727d.bindPopup(popup_6e3be56248f3c62b0fad1adf867816b4)
#         ;
#
#
#
#
#             var marker_d4702c9405cf88903fcbab0fd43c1672 = L.marker(
#                 [46.225517, 6.0830497],
#                 {}
