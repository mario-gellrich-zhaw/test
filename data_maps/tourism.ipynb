# %% [markdown]
# # Import geo-data of "tourism" in Geneva using overpass API

# %% [markdown]
# # Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize
import pandas as pd
from IPython.display import display

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/project_arm_airbnb/data_maps

# %% [markdown]
# ## API request

# %% [markdown]
# ### Touristenattraktionen

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-2"="CH-GE"][admin_level=4];
        node ["tourism"="attraction"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('attraction.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df_attraction = json_normalize(data)

# Number of rows and columns
print(df_attraction.shape)

# First rows
df_attraction.head(5)
# Out:
# (41, 61)
#    type         id        lat       lon tags.archaeological_site  \
# 0  node   25648489  46.205673  6.154324               petroglyph
# 1  node   60018172  46.207381  6.155889                      NaN
# 2  node  139446272  46.128550  5.957381                      NaN
# 3  node  151258480  46.132357  5.955911                      NaN
# 4  node  613159167  46.142711  6.126112                      NaN
#
#     tags.denotation tags.ele  tags.geological        tags.historic  \
# 0  natural_monument    373.6  glacial_erratic  archaeological_site
# 1               NaN      NaN              NaN                  NaN
# 2               NaN      NaN              NaN       boundary_stone
# 3               NaN      NaN              NaN                  NaN
# 4               NaN      NaN              NaN                  yes
#
#   tags.man_made  ... tags.email tags.internet_access tags.leisure tags.level  \
# 0  survey_point  ...        NaN                  NaN          NaN        NaN
# 1           NaN  ...        NaN                  NaN          NaN        NaN
# 2           NaN  ...        NaN                  NaN          NaN        NaN
# 3           NaN  ...        NaN                  NaN          NaN        NaN
# 4         tower  ...        NaN                  NaN          NaN        NaN
#
#   tags.opening_hours tags.length tags.url tags.width tags.alt tags.access
# 0                NaN         NaN      NaN        NaN      NaN         NaN
# 1                NaN         NaN      NaN        NaN      NaN         NaN
# 2                NaN         NaN      NaN        NaN      NaN         NaN
# 3                NaN         NaN      NaN        NaN      NaN         NaN
# 4                NaN         NaN      NaN        NaN      NaN         NaN
#
# [5 rows x 61 columns]

# %%
# load data from df_attraction into locations_attraction
locations_attraction = df_attraction[['lat','lon', "tags.name"]]

#Create map
m = folium.Map(location=[46.2044, 6.1432], zoom_start=12)

# add marker to symbols
for i in range(0, len(locations_attraction)):
    folium.Marker([locations_attraction.iloc[i]['lat'], locations_attraction.iloc[i]['lon']],
                  popup=f"{locations_attraction.iloc[i]['tags.name']}").add_to(m)
    
# plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6540488039df583db4c52cf0f654a158 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6540488039df583db4c52cf0f654a158&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6540488039df583db4c52cf0f654a158 = L.map(
#                 &quot;map_6540488039df583db4c52cf0f654a158&quot;,
#                 {
#                     center: [46.2044, 6.1432],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0df2e3b8299ac4964aaed6fa21475323 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0df2e3b8299ac4964aaed6fa21475323.addTo(map_6540488039df583db4c52cf0f654a158);
#
#
#             var marker_903cc1dee7a3c374cbff553a2ee36cf7 = L.marker(
#                 [46.2056728, 6.1543238],
#                 {}
#             ).addTo(map_6540488039df583db4c52cf0f654a158);
#
#
#         var popup_ad13068fe2c9e8d8d3742355a724a443 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6866264af9c605b68df0c4f95fda74bc = $(`&lt;div id=&quot;html_6866264af9c605b68df0c4f95fda74bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pierre du Niton&lt;/div&gt;`)[0];
#                 popup_ad13068fe2c9e8d8d3742355a724a443.setContent(html_6866264af9c605b68df0c4f95fda74bc);
#
#
#
#         marker_903cc1dee7a3c374cbff553a2ee36cf7.bindPopup(popup_ad13068fe2c9e8d8d3742355a724a443)
#         ;
#
#
#
#
#             var marker_eb028564bb22e70f7d34be771651d19f = L.marker(
#                 [46.2073807, 6.1558891],
#                 {}
#             ).addTo(map_6540488039df583db4c52cf0f654a158);
#
#
#         var popup_8bb5339a236f74520b0f2660e39ddf0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34c3522bbaee46bb8fb8c110ff82ba21 = $(`&lt;div id=&quot;html_34c3522bbaee46bb8fb8c110ff82ba21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jet d&#x27;eau&lt;/div&gt;`)[0];
#                 popup_8bb5339a236f74520b0f2660e39ddf0e.setContent(html_34c3522bbaee46bb8fb8c110ff82ba21);
#
#
#
#         marker_eb028564bb22e70f7d34be771651d19f.bindPopup(popup_8bb5339a236f74520b0f2660e39ddf0e)
#         ;
#
#
#
#
#             var marker_b082b8cff4061de11f43c6a74659feae = L.marker(
#                 [46.1285501, 5.9573812],
#                 {}
#             ).addTo(map_6540488039df583db4c52cf0f654a158);
#
#
#         var popup_cbea4d2787eda7c43c094a8ac702ce0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ffef22c91aa9e60377fa817ecfc1f14 = $(`&lt;div id=&quot;html_0ffef22c91aa9e60377fa817ecfc1f14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Borne n°1&lt;/div&gt;`)[0];
#                 popup_cbea4d2787eda7c43c094a8ac702ce0e.setContent(html_0ffef22c91aa9e60377fa817ecfc1f14);
#
#
#
#         marker_b082b8cff4061de11f43c6a74659feae.bindPopup(popup_cbea4d2787eda7c43c094a8ac702ce0e)
#         ;
#
#
#
#
#             var marker_bfa8d7b6fb4fefb668c9bd5ce27b2ee4 = L.marker(
#                 [46.1323565, 5.9559113],
#                 {}
#             ).addTo(map_6540488039df583db4c52cf0f654a158);
#
#
#         var popup_c1b41f9cacc795e108eddc5a79f465ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d43742cea79333074d29f8280c36d691 = $(`&lt;div id=&quot;html_d43742cea79333074d29f8280c36d691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Le point le plus occidental de Suisse&lt;/div&gt;`)[0];
#                 popup_c1b41f9cacc795e108eddc5a79f465ad.setContent(html_d43742cea79333074d29f8280c36d691);
#
#
#
#         marker_bfa8d7b6fb4fefb668c9bd5ce27b2ee4.bindPopup(popup_c1b41f9cacc795e108eddc5a79f465ad)
#         ;
#
#
#
#
#             var marker_3291199901b2950af0779970306de385 = L.marker(
#                 [46.1427106, 6.126112],
#                 {}
#             ).addTo(map_6540488039df583db4c52cf0f654a158);
#
#
#         var popup_3fd26840706ba70e9b2ab8f17c42becf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_870297d0de97fc88fa9496a141e97b27 = $(`&lt;div id=&quot;html_870297d0de97fc88fa9496a141e97b27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#                 popup_3fd26840706ba70e9b2ab8f17c42becf.setContent(html_870297d0de97fc88fa9496a141e97b27);
#
#
#
#         marker_3291199901b2950af0779970306de385.bindPopup(popup_3fd26840706ba70e9b2ab8f17c42becf)
#         ;
#
#
#
#
#             var marker_e5a0d396ea696dc71364bce38a751cef = L.marker(
#                 [46.2242798, 6.1380784],
#                 {}
#             ).addTo(map_6540488039df583db4c52

# %%
# drop duplicates based on tags.name
locations_attraction = locations_attraction.drop_duplicates(subset="tags.name")
print(locations_attraction.head(5))

# Number of rows and columns
print(locations_attraction.shape)

# Create map
map = folium.Map(location=[locations_attraction.lat.mean(), 
                           locations_attraction.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, locations_attraction in locations_attraction.iterrows():
    folium.Marker([locations_attraction["lat"], 
                   locations_attraction["lon"]], 
                  popup=locations_attraction["tags.name"]).add_to(map)


# Plot map
map
# Out:
#          lat       lon                              tags.name
# 0  46.205673  6.154324                        Pierre du Niton
# 1  46.207381  6.155889                              Jet d'eau
# 2  46.128550  5.957381                              Borne n°1
# 3  46.132357  5.955911  Le point le plus occidental de Suisse
# 4  46.142711  6.126112                                    NaN
# (37, 3)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9da923ab7212b10310a5733ae0ad05c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9da923ab7212b10310a5733ae0ad05c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9da923ab7212b10310a5733ae0ad05c3 = L.map(
#                 &quot;map_9da923ab7212b10310a5733ae0ad05c3&quot;,
#                 {
#                     center: [46.20720735405405, 6.1170715270270275],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9da923ab7212b10310a5733ae0ad05c3);
#
#
#
#
#
#             var tile_layer_0d25b71638df3c21423d68c57a0cc197 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d25b71638df3c21423d68c57a0cc197.addTo(map_9da923ab7212b10310a5733ae0ad05c3);
#
#
#             var marker_696659eab812b98b449a76ee4aa78f4e = L.marker(
#                 [46.2056728, 6.1543238],
#                 {}
#             ).addTo(map_9da923ab7212b10310a5733ae0ad05c3);
#
#
#         var popup_951d17a020b57313e92f5bbfb486f22d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2722d20aabbc67c7bd9e9ce2a7f02995 = $(`&lt;div id=&quot;html_2722d20aabbc67c7bd9e9ce2a7f02995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pierre du Niton&lt;/div&gt;`)[0];
#                 popup_951d17a020b57313e92f5bbfb486f22d.setContent(html_2722d20aabbc67c7bd9e9ce2a7f02995);
#
#
#
#         marker_696659eab812b98b449a76ee4aa78f4e.bindPopup(popup_951d17a020b57313e92f5bbfb486f22d)
#         ;
#
#
#
#
#             var marker_4c04272a62ee4873d688f5eafe7a56f3 = L.marker(
#                 [46.2073807, 6.1558891],
#                 {}
#             ).addTo(map_9da923ab7212b10310a5733ae0ad05c3);
#
#
#         var popup_6b826ca46d96be5442e2cbe9a3c145f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_571f75741b2ea650b2fa8ca72293d282 = $(`&lt;div id=&quot;html_571f75741b2ea650b2fa8ca72293d282&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jet d&#x27;eau&lt;/div&gt;`)[0];
#                 popup_6b826ca46d96be5442e2cbe9a3c145f5.setContent(html_571f75741b2ea650b2fa8ca72293d282);
#
#
#
#         marker_4c04272a62ee4873d688f5eafe7a56f3.bindPopup(popup_6b826ca46d96be5442e2cbe9a3c145f5)
#         ;
#
#
#
#
#             var marker_07dc1ac0868aa23c2bb43937b7829269 = L.marker(
#                 [46.1285501, 5.9573812],
#                 {}
#             ).addTo(map_9da923ab7212b10310a5733ae0ad05c3);
#
#
#         var popup_191cdde3dba72b2679ff00a52b4eec51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e919aeaacff6690e471beb44c99112c7 = $(`&lt;div id=&quot;html_e919aeaacff6690e471beb44c99112c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Borne n°1&lt;/div&gt;`)[0];
#                 popup_191cdde3dba72b2679ff00a52b4eec51.setContent(html_e919aeaacff6690e471beb44c99112c7);
#
#
#
#         marker_07dc1ac0868aa23c2bb43937b7829269.bindPopup(popup_191cdde3dba72b2679ff00a52b4eec51)
#         ;
#
#
#
#
#             var marker_bbf4c540a01075d7099a1494c65454b0 = L.marker(
#                 [46.1323565, 5.9559113],
#                 {}
#             ).addTo(map_9da923ab7212b10310a5733ae0ad05c3);
#
#
#         var popup_dd9e504639a544f16345f1d086a63da1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16230de50c8a90bddb03288cbe39081a = $(`&lt;div id=&quot;html_16230de50c8a90bddb03288cbe39081a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Le point le plus occidental de Suisse&lt;/div&gt;`)[0];
#                 popup_dd9e504639a544f16345f1d086a63da1.setContent(html_16230de50c8a90bddb03288cbe39081a);
#
#
#
#         marker_bbf4c540a01075d7099a1494c65454b0.bindPopup(popup_dd9e504639a544f16345f1d086a63da1)
#         ;
#
#
#
#
#             var marker_c19128946456c725bf207a72cfa5b47d = L.marker(
#                 [46.1427106, 6.126112],
#                 {}
#             ).addTo(map_9da923ab7212b10310a5733ae0ad05c3);
#
#
#         var popup_c8a3acc210284a7676489f8c13b7cd79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7a6456d9a469c8d25fee262519d5ca4 = $(`&lt;div id=&quot;html_a7a6456d9a469c8d25fee262519d5ca4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;nan&lt;/div&gt;`)[0];
#                 popup_c8a3acc210284a7676489f8c13b7cd79.setContent(html_a7a6456d9a469c8d25fee262519d5ca4);
#
#
#
#         marker_c19128946456c725bf207a72cfa5b47d.bindPopup(popup_c8a3acc210284a7676489f8c13b7cd79)
#         ;
#
#
#
#
#             var marker_0b356acc3ee7f0d1cec189cf85094e67 = L.marker(

# %% [markdown]
# ## Museum

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-2"="CH-GE"][admin_level=4];
        node ["tourism"="museum"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('museum.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df_museum = json_normalize(data)

# Number of rows and columns
print(df_museum.shape)

# First rows
df_museum.head(5)
# Out:
# (15, 41)
#    type          id        lat       lon tags.fee tags.museum  \
# 0  node   701851300  46.233972  6.055721       no     science
# 1  node   981690477  46.184291  6.139151       no         NaN
# 2  node   983366077  46.198282  6.108982      NaN         NaN
# 3  node  1768216261  46.220829  6.152126       no         NaN
# 4  node  2021513198  46.198828  6.137523      yes         art
#
#                                 tags.name  \
# 0  Globe de la Science et de l'Innovation
# 1                        Musée de Carouge
# 2                           Musée des EAN
# 3           Musée d'histoire des sciences
# 4                                   MAMCO
#
#                           tags.name:en  \
# 0  The Globe of Science and Innovation
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                              tags.name:es  \
# 0  Globo de la Ciencia y de la Innovación
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                              tags.name:fr  ...  \
# 0  Globe de la Science et de L'innovation  ...
# 1                                     NaN  ...
# 2                           Musée des EAN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
#
#                     tags.contact:instagram  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  https://www.instagram.com/mamco_geneve/
#
#                   tags.contact:twitter     tags.email  \
# 0                                  NaN            NaN
# 1                                  NaN            NaN
# 2                                  NaN            NaN
# 3                                  NaN            NaN
# 4  https://twitter.com/mamco_artmuseum  info@mamco.ch
#
#                     tags.official_name tags.short_name tags.addr:housename  \
# 0                                  NaN             NaN                 NaN
# 1                                  NaN             NaN                 NaN
# 2                                  NaN             NaN                 NaN
# 3                                  NaN             NaN                 NaN
# 4  Musée d’Art Moderne et Contemporain           MAMCO                 NaN
#
#   tags.operator:type tags.description tags.internet_access  \
# 0                NaN              NaN                  NaN
# 1                NaN              NaN                  NaN
# 2                NaN              NaN                  NaN
# 3                NaN              NaN                  NaN
# 4                NaN              NaN                  NaN
#
#   tags.contact:website
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 41 columns]

# %%
# load data from df_museum into locations_museum
locations_museum = df_museum[['lat','lon', "tags.name"]]

#Create map
m = folium.Map(location=[46.2044, 6.1432], zoom_start=12)

# add marker to sympols
for i in range(0, len(locations_museum)):
    folium.Marker([locations_museum.iloc[i]['lat'], locations_museum.iloc[i]['lon']],
                  popup=locations_museum.iloc[i]['tags.name']).add_to(m)
    
# plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf9152ae8b92b84e5f639d25509531e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf9152ae8b92b84e5f639d25509531e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf9152ae8b92b84e5f639d25509531e4 = L.map(
#                 &quot;map_bf9152ae8b92b84e5f639d25509531e4&quot;,
#                 {
#                     center: [46.2044, 6.1432],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7cf5c8be2125c5446387fc050d5a585 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b7cf5c8be2125c5446387fc050d5a585.addTo(map_bf9152ae8b92b84e5f639d25509531e4);
#
#
#             var marker_c9272dfa247d89b54a51792212ba67ae = L.marker(
#                 [46.2339717, 6.0557211],
#                 {}
#             ).addTo(map_bf9152ae8b92b84e5f639d25509531e4);
#
#
#         var popup_f04e9cde73ca4e09d8d294469a99bb0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_283d3ecc0d32b1a1c2fea4c15535b64a = $(`&lt;div id=&quot;html_283d3ecc0d32b1a1c2fea4c15535b64a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Globe de la Science et de l&#x27;Innovation&lt;/div&gt;`)[0];
#                 popup_f04e9cde73ca4e09d8d294469a99bb0d.setContent(html_283d3ecc0d32b1a1c2fea4c15535b64a);
#
#
#
#         marker_c9272dfa247d89b54a51792212ba67ae.bindPopup(popup_f04e9cde73ca4e09d8d294469a99bb0d)
#         ;
#
#
#
#
#             var marker_a4bfd9efa73c976aa19f8b6e9d9f2661 = L.marker(
#                 [46.1842913, 6.1391515],
#                 {}
#             ).addTo(map_bf9152ae8b92b84e5f639d25509531e4);
#
#
#         var popup_0eb4280db052820d2a3a619f50c6a4e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b521d4a9e5a34b7ca82984f5cb23c19 = $(`&lt;div id=&quot;html_1b521d4a9e5a34b7ca82984f5cb23c19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée de Carouge&lt;/div&gt;`)[0];
#                 popup_0eb4280db052820d2a3a619f50c6a4e3.setContent(html_1b521d4a9e5a34b7ca82984f5cb23c19);
#
#
#
#         marker_a4bfd9efa73c976aa19f8b6e9d9f2661.bindPopup(popup_0eb4280db052820d2a3a619f50c6a4e3)
#         ;
#
#
#
#
#             var marker_c5e40d41ce850c4d7528269058ed2510 = L.marker(
#                 [46.1982817, 6.1089823],
#                 {}
#             ).addTo(map_bf9152ae8b92b84e5f639d25509531e4);
#
#
#         var popup_aafbc5d1e5f351cd198e2ba86ec2144a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_383f79528ab801fc7ac659c94b0c06c7 = $(`&lt;div id=&quot;html_383f79528ab801fc7ac659c94b0c06c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée des EAN&lt;/div&gt;`)[0];
#                 popup_aafbc5d1e5f351cd198e2ba86ec2144a.setContent(html_383f79528ab801fc7ac659c94b0c06c7);
#
#
#
#         marker_c5e40d41ce850c4d7528269058ed2510.bindPopup(popup_aafbc5d1e5f351cd198e2ba86ec2144a)
#         ;
#
#
#
#
#             var marker_8ed464bf9527374f392950ecd9883c5c = L.marker(
#                 [46.2208287, 6.1521265],
#                 {}
#             ).addTo(map_bf9152ae8b92b84e5f639d25509531e4);
#
#
#         var popup_df06d6baebfeff008a7bfae0e68576c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_072a27775b7f242d51731bcd99ee91d3 = $(`&lt;div id=&quot;html_072a27775b7f242d51731bcd99ee91d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée d&#x27;histoire des sciences&lt;/div&gt;`)[0];
#                 popup_df06d6baebfeff008a7bfae0e68576c3.setContent(html_072a27775b7f242d51731bcd99ee91d3);
#
#
#
#         marker_8ed464bf9527374f392950ecd9883c5c.bindPopup(popup_df06d6baebfeff008a7bfae0e68576c3)
#         ;
#
#
#
#
#             var marker_310368685407c6e17fb68effc173795e = L.marker(
#                 [46.1988283, 6.1375228],
#                 {}
#             ).addTo(map_bf9152ae8b92b84e5f639d25509531e4);
#
#
#         var popup_91c2987c93e41f722e61c5229a3ab727 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_146a8391b8fd3cae6e3da7930c5bd385 = $(`&lt;div id=&quot;html_146a8391b8fd3cae6e3da7930c5bd385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAMCO&lt;/div&gt;`)[0];
#                 popup_91c2987c93e41f722e61c5229a3ab727.setContent(html_146a8391b8fd3cae6e3da7930c5bd385);
#
#
#
#         marker_310368685407c6e17fb68effc173795e.bindPopup(popup_91c2987c93e41f722e61c5229a3ab727)
#         ;
#
#
#
#
#             var marker_a9be288d6b929a0a956494d6db983ddd = L.marker(
#                 [46.225517, 6.0830497],
#                 {}

# %%
# drop duplicates based on tags.name
locations_museum = locations_museum.drop_duplicates(subset="tags.name")
print(locations_museum.head(5))

# Number of rows and columns
print(locations_museum.shape)

# Create map
map = folium.Map(location=[locations_museum.lat.mean(), 
                           locations_museum.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, locations_museum in locations_museum.iterrows():
    folium.Marker([locations_museum["lat"], 
                   locations_museum["lon"]], 
                  popup=locations_museum["tags.name"]).add_to(map)


# Plot map
map
# Out:
#          lat       lon                               tags.name
# 0  46.233972  6.055721  Globe de la Science et de l'Innovation
# 1  46.184291  6.139151                        Musée de Carouge
# 2  46.198282  6.108982                           Musée des EAN
# 3  46.220829  6.152126           Musée d'histoire des sciences
# 4  46.198828  6.137523                                   MAMCO
# (15, 3)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa9a30a6336f5d1c350dc19d806057b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa9a30a6336f5d1c350dc19d806057b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa9a30a6336f5d1c350dc19d806057b8 = L.map(
#                 &quot;map_aa9a30a6336f5d1c350dc19d806057b8&quot;,
#                 {
#                     center: [46.20818418, 6.12061794],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aa9a30a6336f5d1c350dc19d806057b8);
#
#
#
#
#
#             var tile_layer_9bbc74f4f7f49d496cb9863158fde06a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9bbc74f4f7f49d496cb9863158fde06a.addTo(map_aa9a30a6336f5d1c350dc19d806057b8);
#
#
#             var marker_39f7dcadf2d9e6bea42a1fd95a65488d = L.marker(
#                 [46.2339717, 6.0557211],
#                 {}
#             ).addTo(map_aa9a30a6336f5d1c350dc19d806057b8);
#
#
#         var popup_17c22d2397196874247ccdacf67368eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9b576ee211b37d675645ba42254bfb3 = $(`&lt;div id=&quot;html_d9b576ee211b37d675645ba42254bfb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Globe de la Science et de l&#x27;Innovation&lt;/div&gt;`)[0];
#                 popup_17c22d2397196874247ccdacf67368eb.setContent(html_d9b576ee211b37d675645ba42254bfb3);
#
#
#
#         marker_39f7dcadf2d9e6bea42a1fd95a65488d.bindPopup(popup_17c22d2397196874247ccdacf67368eb)
#         ;
#
#
#
#
#             var marker_995bb9922c2ef1c9a5817ed6f953bf46 = L.marker(
#                 [46.1842913, 6.1391515],
#                 {}
#             ).addTo(map_aa9a30a6336f5d1c350dc19d806057b8);
#
#
#         var popup_f92278c7b92b0260250ef3cfc6a30b58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6720a7d44d2176af2085294f8ab3eefa = $(`&lt;div id=&quot;html_6720a7d44d2176af2085294f8ab3eefa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée de Carouge&lt;/div&gt;`)[0];
#                 popup_f92278c7b92b0260250ef3cfc6a30b58.setContent(html_6720a7d44d2176af2085294f8ab3eefa);
#
#
#
#         marker_995bb9922c2ef1c9a5817ed6f953bf46.bindPopup(popup_f92278c7b92b0260250ef3cfc6a30b58)
#         ;
#
#
#
#
#             var marker_b81e097bc7b20a70d07d5018a1bb0f39 = L.marker(
#                 [46.1982817, 6.1089823],
#                 {}
#             ).addTo(map_aa9a30a6336f5d1c350dc19d806057b8);
#
#
#         var popup_ab023fe2ad58ed6dcbf9411556716637 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86a7276edc58915dc835c803c64161df = $(`&lt;div id=&quot;html_86a7276edc58915dc835c803c64161df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée des EAN&lt;/div&gt;`)[0];
#                 popup_ab023fe2ad58ed6dcbf9411556716637.setContent(html_86a7276edc58915dc835c803c64161df);
#
#
#
#         marker_b81e097bc7b20a70d07d5018a1bb0f39.bindPopup(popup_ab023fe2ad58ed6dcbf9411556716637)
#         ;
#
#
#
#
#             var marker_6027ad60f0ced9fda17a6f591f70bc2b = L.marker(
#                 [46.2208287, 6.1521265],
#                 {}
#             ).addTo(map_aa9a30a6336f5d1c350dc19d806057b8);
#
#
#         var popup_228d46df10f77201a5f0d01881ca202b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_137de8c2fd1e9e1d19c8e07e3b58b898 = $(`&lt;div id=&quot;html_137de8c2fd1e9e1d19c8e07e3b58b898&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Musée d&#x27;histoire des sciences&lt;/div&gt;`)[0];
#                 popup_228d46df10f77201a5f0d01881ca202b.setContent(html_137de8c2fd1e9e1d19c8e07e3b58b898);
#
#
#
#         marker_6027ad60f0ced9fda17a6f591f70bc2b.bindPopup(popup_228d46df10f77201a5f0d01881ca202b)
#         ;
#
#
#
#
#             var marker_cf7b91856c22330fb3df2beba47b906a = L.marker(
#                 [46.1988283, 6.1375228],
#                 {}
#             ).addTo(map_aa9a30a6336f5d1c350dc19d806057b8);
#
#
#         var popup_ee5f22534ee62a05f86d9c04f289700d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a12908ff4f5b001bace5c237f4fdcdc0 = $(`&lt;div id=&quot;html_a12908ff4f5b001bace5c237f4fdcdc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MAMCO&lt;/div&gt;`)[0];
#                 popup_ee5f22534ee62a05f86d9c04f289700d.setContent(html_a12908ff4f5b001bace5c237f4fdcdc0);
#
#
#
#         marker_cf7b91856c22330fb3df2beba47b906a.bindPopup(popup_ee5f22534ee62a05f86d9c04f289700d)
#         ;
#
#
#
#
#             var marker_6face2b18551a5a67576a6d857ec3a86 =

# %% [markdown]
# ## Combine museum and attraction dataframes

# %%
# create new data frame for museums to be used in the final data frame
dfm = df_museum[['id', 'lat', 'lon', 'tags.name', 'tags.tourism']]
dfm.rename(columns={'tags.name': 'name', 'tags.tourism': 'category'}, inplace=True)
dfm.head()
# Out:
#            id        lat       lon                                    name  \
# 0   701851300  46.233972  6.055721  Globe de la Science et de l'Innovation
# 1   981690477  46.184291  6.139151                        Musée de Carouge
# 2   983366077  46.198282  6.108982                           Musée des EAN
# 3  1768216261  46.220829  6.152126           Musée d'histoire des sciences
# 4  2021513198  46.198828  6.137523                                   MAMCO
#
#   category
# 0   museum
# 1   museum
# 2   museum
# 3   museum
# 4   museum

# %%
# create new data frame for museums to be used in the final data frame
dfa = df_attraction[['id', 'lat', 'lon', 'tags.name', 'tags.tourism']]
dfa.rename(columns={'tags.name': 'name', 'tags.tourism': 'category'}, inplace=True)

# drop missing values
dfa = dfa.dropna()
dfa.head()

# add the museums to the attractions data frame
df_tourist = pd.concat([dfm, dfa], ignore_index=True)

# print shape of the data
print(f"Dataframe shape: {df_tourist.shape}")
df_tourist.head()
# Out:
# Dataframe shape: (52, 5)
#            id        lat       lon                                    name  \
# 0   701851300  46.233972  6.055721  Globe de la Science et de l'Innovation
# 1   981690477  46.184291  6.139151                        Musée de Carouge
# 2   983366077  46.198282  6.108982                           Musée des EAN
# 3  1768216261  46.220829  6.152126           Musée d'histoire des sciences
# 4  2021513198  46.198828  6.137523                                   MAMCO
#
#   category
# 0   museum
# 1   museum
# 2   museum
# 3   museum
# 4   museum

# %%
# check for duplicates
duplicates = df_tourist.duplicated(subset=['name']).sum()
print(f"Number of duplicates: {duplicates}")

# drop duplicates
df_tourist = df_tourist.drop_duplicates(subset=['name'])
print(f"Dataframe shape: {df_tourist.shape}")

# check for duplicates again
duplicates = df_tourist.duplicated(subset=['name']).sum()
print(f"Number of duplicates new: {duplicates}")

# print shape of dataframe
print(f"Dataframe shape final: {df_tourist.shape}")
# Out:
# Number of duplicates: 1
# Dataframe shape: (51, 5)
# Number of duplicates new: 0
# Dataframe shape final: (51, 5)

# %% [markdown]
# ## Store df_ta in SQLite database

# %%
# store data in sqlite database
import sqlite3
import fnmatch

# Function to close a sqlite db-connection
def check_conn(conn):
     try:
        conn.cursor()
        return True
     except Exception as ex:
        return False

# create a connection to the database
conn = sqlite3.connect('/workspaces/project_arm_airbnb/data/tourist.db')

# Create cursor object to execute SQL commands
cursor = conn.cursor()

# Show dbs in the directory
flist = fnmatch.filter(os.listdir('.'), '*.db')
for i in flist:
    print(i)

# store the data in the database
df_tourist.to_sql('tourist', conn, if_exists='replace', index=False)
# Out:
# 51

# %%
# query the data from the database to check if the data was stored correctly
query = "SELECT * FROM tourist"
df2 = pd.read_sql(query, conn)

print(df2.shape)
df2.head()
# Out:
# (51, 5)
#            id        lat       lon                                    name  \
# 0   701851300  46.233972  6.055721  Globe de la Science et de l'Innovation
# 1   981690477  46.184291  6.139151                        Musée de Carouge
# 2   983366077  46.198282  6.108982                           Musée des EAN
# 3  1768216261  46.220829  6.152126           Musée d'histoire des sciences
# 4  2021513198  46.198828  6.137523                                   MAMCO
#
#   category
# 0   museum
# 1   museum
# 2   museum
# 3   museum
# 4   museum

# %%
# Close db connection (if open)
try:
    if check_conn(conn):
        conn.close()
    else:
        pass
except:
    pass

# Status (True = open, False = closed)
print(check_conn(conn))
# Out:
# False

# %% [markdown]
# ### Jupyter notebook --footer info--

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2025-01-08 07:39:08
# Python Version: 3.11.10
# -----------------------------------
