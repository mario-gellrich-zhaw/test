# %% [markdown]
# # Writing data to and reading data from a Database using Python

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import sqlite3
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Function to close a sqlite db-connection
def check_conn(conn):
     try:
        conn.cursor()
        return True
     except Exception as ex:
        return False

# Get current working directory
print(os.getcwd())
# Out:
# /workspaces/project_arm_airbnb

# %% [markdown]
# ## Create sqlite data base

# %%
# Create data base
conn = sqlite3.connect('./data_kaggle/listings_1_database.db') 

# Create cursor object to execute SQL commands
cursor = conn.cursor()

# Show dbs in the directory
flist = fnmatch.filter(os.listdir('.'), '*.db')
for i in flist:
    print(i)

# %% [markdown]
# ## Create SQL-table in the database

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS listings_1_table (Id VARCHAR(50),
                                                               Roomtype VARCHAR(50),
                                                               lon DECIMAL(8,2),
                                                               lat DECIMAL(8,2),
                                                               Price DECIMAL(8,2))''')
# Confirm changes to the table
conn.commit()

# %% [markdown]
# ## Read data from file to data frame

# %%
df = pd.read_csv('./data_kaggle/listings_1.csv',
                  sep=',', 
                  encoding='utf-8')[['id', 'neighbourhood_cleansed', 'latitude', 'longitude','property_type', 'room_type', 'price', 'accommodates', 'bathrooms_text', 'amenities', 'review_scores_rating', 'review_scores_location', 'instant_bookable', 'calculated_host_listings_count']]
print(df.shape)
df.head(5)
# Out:
# (2069, 14)
#        id neighbourhood_cleansed  latitude  longitude  \
# 0   42515      Commune de Genève  46.20140    6.15507
# 1   44959      Commune de Genève  46.19704    6.16076
# 2  194110      Commune de Genève  46.20420    6.16067
# 3  276025                Versoix  46.27944    6.16724
# 4  325986      Commune de Genève  46.21428    6.14610
#
#                property_type        room_type    price  accommodates  \
# 0  Private room in apartment     Private room   $72.00             1
# 1  Private room in apartment     Private room   $68.00             1
# 2           Entire apartment  Entire home/apt  $135.00             4
# 3           Entire apartment  Entire home/apt   $65.00             5
# 4           Entire apartment  Entire home/apt  $150.00             2
#
#      bathrooms_text                                          amenities  \
# 0         1.5 baths  ["Cable TV", "Dishes and silverware", "Washer"...
# 1  1.5 shared baths  ["Extra pillows and blankets", "Cable TV", "Po...
# 2            1 bath  ["Extra pillows and blankets", "Cable TV", "Di...
# 3            1 bath  ["Extra pillows and blankets", "Portable fans"...
# 4         1.5 baths  ["Dishes and silverware", "Washer", "TV", "Smo...
#
#    review_scores_rating  review_scores_location instant_bookable  \
# 0                  4.69                    4.79                f
# 1                  4.87                    4.72                f
# 2                  4.50                    4.85                f
# 3                  4.62                    4.75                t
# 4                  4.84                    4.76                f
#
#    calculated_host_listings_count
# 0                               1
# 1                               1
# 2                               1
# 3                               1
# 4                               1

# %% [markdown]
# ## Write data to the SQL-table in data base

# %%
df.to_sql(name = 'listings_1_table',
          con = conn,
          index = False,
          if_exists = 'replace')
# Out:
# 2069

# %% [markdown]
# ## Query the SQL-table

# %%
# Query the SQL-table
cursor.execute('''SELECT *
               FROM listings_1_table
               WHERE bathrooms_text >=1''')

df = pd.DataFrame(cursor.fetchall(), 
                  columns=['id', 'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'price', 'accommodates', 'bathrooms_text', 'amenities', 'review_scores_rating', 'review_scores_location', 'instant_bookable', 'calculated_host_listings_count'])    
df
# Out:
#             id neighbourhood_cleansed   latitude  longitude  \
# 0        42515      Commune de Genève  46.201400   6.155070
# 1        44959      Commune de Genève  46.197040   6.160760
# 2       194110      Commune de Genève  46.204200   6.160670
# 3       276025                Versoix  46.279440   6.167240
# 4       325986      Commune de Genève  46.214280   6.146100
# ...        ...                    ...        ...        ...
# 2053  50639175                Carouge  46.175170   6.139500
# 2054  50665001      Commune de Genève  46.210240   6.146540
# 2055  50675141                Versoix  46.274420   6.167230
# 2056  50687989      Commune de Genève  46.200215   6.147685
# 2057  50696863      Commune de Genève  46.210868   6.146524
#
#                   property_type        room_type    price  accommodates  \
# 0     Private room in apartment     Private room   $72.00             1
# 1     Private room in apartment     Private room   $68.00             1
# 2              Entire apartment  Entire home/apt  $135.00             4
# 3              Entire apartment  Entire home/apt   $65.00             5
# 4              Entire apartment  Entire home/apt  $150.00             2
# ...                         ...              ...      ...           ...
# 2053      Private room in villa     Private room   $36.00             1
# 2054           Entire apartment  Entire home/apt  $100.00             2
# 2055  Private room in apartment     Private room   $65.00             1
# 2056           Entire apartment  Entire home/apt   $64.00             2
# 2057           Entire apartment  Entire home/apt  $150.00             2
#
#         bathrooms_text                                          amenities  \
# 0            1.5 baths  ["Cable TV", "Dishes and silverware", "Washer"...
# 1     1.5 shared baths  ["Extra pillows and blankets", "Cable TV", "Po...
# 2               1 bath  ["Extra pillows and blankets", "Cable TV", "Di...
# 3               1 bath  ["Extra pillows and blankets", "Portable fans"...
# 4            1.5 baths  ["Dishes and silverware", "Washer", "TV", "Smo...
# ...                ...                                                ...
# 2053    1 private bath  ["Extra pillows and blankets", "Lock on bedroo...
# 2054            1 bath  ["Wifi", "Hair dryer", "Long term stays allowe...
# 2055     1 shared bath  ["Wifi", "Long term stays allowed", "Lock on b...
# 2056            1 bath  ["Cooking basics", "Hair dryer", "Elevator", "...
# 2057            1 bath  ["Wifi", "Hair dryer", "Essentials", "TV", "Ho...
#
#       review_scores_rating  review_scores_location instant_bookable  \
# 0                     4.69                    4.79                f
# 1                     4.87                    4.72                f
# 2                     4.50                    4.85                f
# 3                     4.62                    4.75                t
# 4                     4.84                    4.76                f
# ...                    ...                     ...              ...
# 2053                   NaN                     NaN                f
# 2054                   NaN                     NaN                t
# 2055                   NaN                     NaN                t
# 2056                   NaN                     NaN                t
# 2057                   NaN                     NaN                t
#
#       calculated_host_listings_count
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
# ...                              ...
# 2053                               2
# 2054                               3
# 2055                               1
# 2056                               1
# 2057                               3
#
# [2058 rows x 14 columns]
